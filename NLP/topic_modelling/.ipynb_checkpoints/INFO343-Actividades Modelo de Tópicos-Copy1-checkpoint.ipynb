# %% [markdown]
# ## <h1 align="center">Actividad: Agrupar datos textuales con el Modelo de Tópicos y el algoritmo Latent Dirichlet Allocation (LDA)</h3>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <h2> Preámbulo</h2>
# <p> Esta actividad se inspira de ejercicios disponibles en los recursos siguientes:<p>
# <ul>
#     <li>Biblioteca <a href="http://scikit-learn.org/stable/install.html/">SciKit-learn</a> de Python</li>
#     <li>Código disponible en  <a href="https://github.com/lda-project/lda/">lda-project</a></li>
# </ul>
# <p> La actividad requiere el uso de Python 3.x y <a href="http://jupyter.org/install">Jupyter Notebook</a>. El código entregado fue probado con Python 3.6.1. Para saber cuál versión de Python usted está utilizando, ejecutar la celda siguiente (está información es importante cuando se necesitará instalar nuevos paquetes.)
# </p>
# </div>

# %% [markdown]
# <div style="border: 2px solid #D24747; background-color:#F8B4B4">
# <h2>Objetivos de la actividad</h2>
# <p>El <b>objetivo general</b> de esta actividad consiste en  explorar la estructura oculta de un conjunto de datos textuales.</p>
# <p> Comenzaremos por utilizar un  algoritmo de clustering tradicional como Kmeans para explorar datos textuales, considerando la medida tf-idf por cada término presente en cada texto, para caracterizar los textos y construir distancias entre ellos.</p>
# <p>En una segunda fase utilizaremos el <a href="https://drive.google.com/open?id=1rSQPJvRVj0V_IChzspQMRPNwlDTkHYHp"> Modelo Probabilista De Tópicos </a> para descubrir tópicos en los textos. Para ello se utilizará el algoritmo de asignación de tópicos latentes conocido como <a href= "https://drive.google.com/open?id=1BobImO3192hifZPLXowd14gryVAUzBPW">Latent Dirichlet Allocation (LDA)</a>. El enfoque es probabilista, por lo que el resultado del algoritmo es descubrir tópicos en los textos (el número de tópicos es definido por el analista) y asignar una distribución de probabilidad de tópicos en cada texto.</p>  Dependiendo del tamaño de los textos, es también posible agruparlos de acuerdo al tópico con mayor representación en cada uno, lo que permitirá comparar esta metodología con los algoritmos de clustering clásicos.</p> </div>

# %% [markdown]
# <div style="border: 2px solid #D24747; background-color:#F8B4B4">
# <p>Utilizaremos las 100 primeras noticias del conjunto de datos trabajado en la sesion anterior, provenientes de datos de el diario La Tercera.</p>
# <p>El primer paso es la lectura de datos: </p></div>

# %%
import pandas as pd

DATASET_CSV="sophia_latercera-1000.csv"

df = pd.read_csv(DATASET_CSV,sep='|',error_bad_lines=False,header=None)
df[0] = pd.to_datetime(df[0])

texts=df[[0,3]]
texts.columns = ['fecha', 'noticia']
noticias = texts.noticia[1:100]
len(noticias)
# Out:
# 99

# %%
import spacy
nlp = spacy.load("es_core_news_sm")

def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = []
    doc = nlp(sentence.lower().strip())
    for token in doc:
        if not token.is_stop and not token.is_punct and not token.is_digit and not token.like_num:
            mytokens.append(token.lemma_)
    return mytokens

# %%
#Utilizando Kmeans y tf-idf para realizar un primer agrupamiento de las noticias
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

myStopWords=['a','e','o','u','y']
vectorizer = TfidfVectorizer(tokenizer=spacy_tokenizer, stop_words=myStopWords, ngram_range=(1,2))

X=vectorizer.fit_transform(noticias) 
X_term = vectorizer.get_feature_names()

X
# Out:
# <99x22786 sparse matrix of type '<class 'numpy.float64'>'
# 	with 31150 stored elements in Compressed Sparse Row format>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


num_k = range(1, 10)
inertias = []

for k in num_k:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k, n_init=10)

    # Fit model to samples
    model.fit(X)

    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)


# Plot ks vs inertias
plt.plot(num_k, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(num_k)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº1: Explore las clases TfidfVectorizer, CountVectorizer. ¿Qué rol cumplen? ¿Qué tratamiento premilinar de textos se ha hecho en este caso? ¿Qué rol cumple n_gram?</p>
# <p>Pregunta Nº2: A partir del gráfico, justifique el número de clusters para estos datos.</p>
# </div>

# %%
from matplotlib.pylab import hist, show
true_k = 6
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=10)
model.fit(X)
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

for i in range(true_k):
    cluster_words = np.array(terms)[order_centroids[i, :15]]
    print('Cluster {}: {}'.format(i, ' '.join(cluster_words)))
# Out:
# Top terms per cluster:
# Cluster 0: colo colo colo boliviano suazo endler copar libertador choquehuanca serrar libertador pared albo acá copar puerto aricar
# Cluster 1: the película    estrenar   año spice    júpiter ruiz juno anunciar corear planeta restaurar
# Cluster 2:    gobernar político educación reformar    presidente país ministro sistema social ley gratuidad procesar mapuche
# Cluster 3: club anfp fútbol copar jugar año jugador chile sentir    selección deportar deporte gente partir
# Cluster 4: $ preciar comprador euro cerrar vendedor $ comprador euro $ reventa real cobrar anual entrar región dólar
# Cluster 5: millón dólar operación delito chang chino deuda año casino farc abogar escobar sun millón dólar peso

# %%
#Generando algunos gráficos de los resultados
labels = model.predict(X)
plt.scatter(range(99),labels,c=labels)
show()
hist(labels,bins=np.arange(-0.5,5.6,1),alpha=0.5,rwidth=0.9,density=True)
show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº3:Explore diversos valores en los parámetros de n_init y max_iter. ¿tienen influencia en los resultados? ¿Por qué? Describa e interprete los resultados.</p></div>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #F8B4B4">
# <p>En lo que sigue se construye un modelo probabilista de tópicos, considerando de 1 a 9 tópicos (para comparar con Kmeans
#  y el algoritmo LDA estimado con el <a href="https://drive.google.com/open?id=1AoCcmg91Y1yRwM_Ox4Nvf6PGSQ9TybpE">, método de Bayes Variacional</a>, disponible como desarrollo en <a href="http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html">sklearn-lda.</a></p>
# Previo a ello se utiliza la clase CountVectorizer y su función fit_transform que permite construir una matriz tf (DTM, Document-Term Matrix) que contiene la frecuencia de aparición de cada término del vocabulario en cada texto analizado. En la definición de la clase se especifica que:
# <ol>
#     <li>los términos que  aparecen sólo una vez en algún texto no serán considerados en el vocabulario (min_df=2)</li>
#     <li> los términos que  aparecen en mas del 95% de los textos no serán considerados en el vocabulario (max_df=0.95)</li>
#     <li> se considera adicionalmente un conjunto de stop words construido ad-hoc, posible de refinar</li>
# </ol></div>

# %%
#Aplicando Modelos Probabilistas de Tópicos y LDA
from sklearn.decomposition import LatentDirichletAllocation

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()
    
myStopWords=['a','e','o','u','y']
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                stop_words=myStopWords,tokenizer=spacy_tokenizer, ngram_range=(1,2))
tf = tf_vectorizer.fit_transform(noticias)
diccionario= tf_vectorizer.get_feature_names()


perp = []
for k in num_k:
    #Estimación de LDA con Bayes Variacional
    lda = LatentDirichletAllocation(n_components=k, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

    lda.fit(tf)
    #Cálculo de índice de ajuste de los datos
    perp.append(lda.perplexity(tf))

plt.plot(num_k, perp, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('perplexity')
plt.xticks(num_k)
plt.show()

#print("\nTopics in LDA model:")
#print_top_words(lda, diccionario, 15)

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº4: Indage sobre la medida perplexity, ¿Cómo se interpreta el valor obtenido?
# </p></div>

# %%
#Generando algunos gráficos de los resultados
from matplotlib.pylab import hist, show
import seaborn as sns

lda = LatentDirichletAllocation(n_components=true_k, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
y=lda.fit_transform(tf)


#distribución de tópicos en todos los documentos
dist = sum(y)/len(noticias)
print(dist)

w=np.arange(0,true_k)
print(w)
plt.bar(w,height=dist,alpha=0.5,tick_label=w)
show()
#distribución de tópicos en el documento 100
plt.bar(w,height=y[98],alpha=0.5,tick_label=w)
show()


#frecuencia de palabras por tópico
n_top_words=15
numo =np.arange(0,n_top_words)
for idx,topic in enumerate(lda.components_):
    d =[]
    s = []
    for i in topic.argsort()[:-n_top_words - 1:-1]:
          s.append(diccionario[i])
          d.append(topic[i])
    
    plt.barh(numo,width=d,alpha=0.5,tick_label=s)
    show()
# Out:
# [0.10381865 0.31337154 0.10731524 0.276455   0.19738916 0.00165042]
# [0 1 2 3 4 5]

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº5: Interprete estos gráficos.
# </p></div>

# %%
#calculando cluster en base al tópico mas frecuente
z=[]
for i in range(len(noticias)):
    z.append(np.argmax(y[i]))
plt.scatter(range(99),z,c=z)

#distribución de cluster de acuerdo al cálculo anterior
show()
hist(z,bins=np.arange(-0.5,5.6,1),alpha=0.5,rwidth=0.9,density=True)
show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº6: ¿Cómo se comparan estos resultados con los de  Kmeans?
# </p></div>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #F8B4B4">
# <p>Una nueva estimación para algoritmo LDA considerando <a href="https://drive.google.com/open?id=1oSRRvG_W0UaH0l4o9f5ClEyWuGY1j-s0"> Gibbs Sampling</a>, disponible como desarrollo en <a href="https://github.com/lda-project/lda/">lda-project.</a></p>
# </div>

# %%
import lda

model = lda.LDA(n_topics=true_k, n_iter=5000, alpha=0.1, eta=0.1, random_state=3)
model.fit(tf)  # model.fit_transform(X) is also available

topic_word = model.topic_word_  # model.components_ also works
n_top_words=10
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(diccionario)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# INFO:lda:n_documents: 99
# INFO:lda:vocab_size: 2497
# INFO:lda:n_words: 15052
# INFO:lda:n_topics: 6
# INFO:lda:n_iter: 5000
# /home/leo/Escritorio/magister_uach/env/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:<0> log likelihood: -150424
# INFO:lda:<10> log likelihood: -125515
# INFO:lda:<20> log likelihood: -121893
# INFO:lda:<30> log likelihood: -120654
# INFO:lda:<40> log likelihood: -120178
# INFO:lda:<50> log likelihood: -119774
# INFO:lda:<60> log likelihood: -119406
# INFO:lda:<70> log likelihood: -119191
# INFO:lda:<80> log likelihood: -119152
# INFO:lda:<90> log likelihood: -119151
# INFO:lda:<100> log likelihood: -119128
# INFO:lda:<110> log likelihood: -119530
# INFO:lda:<120> log likelihood: -119279
# INFO:lda:<130> log likelihood: -118871
# INFO:lda:<140> log likelihood: -119085
# INFO:lda:<150> log likelihood: -118968
# INFO:lda:<160> log likelihood: -118997
# INFO:lda:<170> log likelihood: -118765
# INFO:lda:<180> log likelihood: -118833
# INFO:lda:<190> log likelihood: -118791
# INFO:lda:<200> log likelihood: -118548
# INFO:lda:<210> log likelihood: -118779
# INFO:lda:<220> log likelihood: -118899
# INFO:lda:<230> log likelihood: -118641
# INFO:lda:<240> log likelihood: -118524
# INFO:lda:<250> log likelihood: -118632
# INFO:lda:<260> log likelihood: -118585
# INFO:lda:<270> log likelihood: -118662
# INFO:lda:<280> log likelihood: -118904
# INFO:lda:<290> log likelihood: -118819
# INFO:lda:<300> log likelihood: -118748
# INFO:lda:<310> log likelihood: -118563
# INFO:lda:<320> log likelihood: -118649
# INFO:lda:<330> log likelihood: -118790
# INFO:lda:<340> log likelihood: -118925
# INFO:lda:<350> log likelihood: -118975
# INFO:lda:<360> log likelihood: -118732
# INFO:lda:<370> log likelihood: -118766
# INFO:lda:<380> log likelihood: -118976
# INFO:lda:<390> log likelihood: -118803
# INFO:lda:<400> log likelihood: -118553
# INFO:lda:<410> log likelihood: -118818
# INFO:lda:<420> log likelihood: -118840
# INFO:lda:<430> log likelihood: -118652
# INFO:lda:<440> log likelihood: -118736
# INFO:lda:<450> log likelihood: -118748
# INFO:lda:<460> log likelihood: -118541
# INFO:lda:<470> log likelihood: -118584
# INFO:lda:<480> log likelihood: -118568
# INFO:lda:<490> log likelihood: -118593
# INFO:lda:<500> log likelihood: -118673
# INFO:lda:<510> log likelihood: -118682
# INFO:lda:<520> log likelihood: -118378
# INFO:lda:<530> log likelihood: -118579
# INFO:lda:<540> log likelihood: -118658
# INFO:lda:<550> log likelihood: -118567
# INFO:lda:<560> log likelihood: -118898
# INFO:lda:<570> log likelihood: -118620
# INFO:lda:<580> log likelihood: -118366
# INFO:lda:<590> log likelihood: -118706
# INFO:lda:<600> log likelihood: -118613
# INFO:lda:<610> log likelihood: -118741
# INFO:lda:<620> log likelihood: -118661
# INFO:lda:<630> log likelihood: -118482
# INFO:lda:<640> log likelihood: -118799
# INFO:lda:<650> log likelihood: -118746
# INFO:lda:<660> log likelihood: -118541
# INFO:lda:<670> log likelihood: -118683
# INFO:lda:<680> log likelihood: -118598
# INFO:lda:<690> log likelihood: -118587
# INFO:lda:<700> log likelihood: -118667
# INFO:lda:<710> log likelihood: -118547
# INFO:lda:<720> log likelihood: -118666
# INFO:lda:<730> log likelihood: -118802
# INFO:lda:<740> log likelihood: -118890
# INFO:lda:<750> log likelihood: -118725
# INFO:lda:<760> log likelihood: -118946
# INFO:lda:<770> log likelihood: -118674
# INFO:lda:<780> log likelihood: -118633
# INFO:lda:<790> log likelihood: -118738
# INFO:lda:<800> log likelihood: -118702
# INFO:lda:<810> log likelihood: -118473
# INFO:lda:<820> log likelihood: -118623
# INFO:lda:<830> log likelihood: -118703
# INFO:lda:<840> log likelihood: -118680
# INFO:lda:<850> log likelihood: -118739
# INFO:lda:<860> log likelihood: -118783
# INFO:lda:<870> log likelihood: -118909
# INFO:lda:<880> log likelihood: -118830
# INFO:lda:<890> log likelihood: -118604
# INFO:lda:<900> log likelihood: -118925
# INFO:lda:<910> log likelihood: -118807
# INFO:lda:<920> log likelihood: -118795
# INFO:lda:<930> log likelihood: -118592
# INFO:lda:<940> log likelihood: -118590
# INFO:lda:<950> log likelihood: -118876
# INFO:lda:<960> log likelihood: -118595
# INFO:lda:<970> log likelihood: -118711
# INFO:lda:<980> log likelihood: -118526
# INFO:lda:<990> log likelihood: -118860
# INFO:lda:<1000> log likelihood: -118815
# INFO:lda:<1010> log likelihood: -118755
# INFO:lda:<1020> log likelihood: -118765
# INFO:lda:<1030> log likelihood: -118591
# INFO:lda:<1040> log likelihood: -118863
# INFO:lda:<1050> log likelihood: -118825
# INFO:lda:<1060> log likelihood: -118811
# INFO:lda:<1070> log likelihood: -118596
# INFO:lda:<1080> log likelihood: -118610
# INFO:lda:<1090> log likelihood: -118791
# INFO:lda:<1100> log likelihood: -118535
# INFO:lda:<1110> log likelihood: -118768
# INFO:lda:<1120> log likelihood: -118934
# INFO:lda:<1130> log likelihood: -118685
# INFO:lda:<1140> log likelihood: -118716
# INFO:lda:<1150> log likelihood: -118696
# INFO:lda:<1160> log likelihood: -118462
# INFO:lda:<1170> log likelihood: -118544
# INFO:lda:<1180> log likelihood: -118764
# INFO:lda:<1190> log likelihood: -118687
# INFO:lda:<1200> log likelihood: -118685
# INFO:lda:<1210> log likelihood: -118675
# INFO:lda:<1220> log likelihood: -118908
# INFO:lda:<1230> log likelihood: -118390
# INFO:lda:<1240> log likelihood: -118762
# INFO:lda:<1250> log likelihood: -118686
# INFO:lda:<1260> log likelihood: -118680
# INFO:lda:<1270> log likelihood: -118781
# INFO:lda:<1280> log likelihood: -118695
# INFO:lda:<1290> log likelihood: -118778
# INFO:lda:<1300> log likelihood: -118426
# INFO:lda:<1310> log likelihood: -118665
# INFO:lda:<1320> log likelihood: -118707
# INFO:lda:<1330> log likelihood: -118739
# INFO:lda:<1340> log likelihood: -118716
# INFO:lda:<1350> log likelihood: -118530
# INFO:lda:<1360> log likelihood: -118842
# INFO:lda:<1370> log likelihood: -118556
# INFO:lda:<1380> log likelihood: -118527
# INFO:lda:<1390> log likelihood: -118504
# INFO:lda:<1400> log likelihood: -118533
# INFO:lda:<1410> log likelihood: -118494
# INFO:lda:<1420> log likelihood: -118631
# INFO:lda:<1430> log likelihood: -118533
# INFO:lda:<1440> log likelihood: -118841
# INFO:lda:<1450> log likelihood: -118911
# INFO:lda:<1460> log likelihood: -118747
# INFO:lda:<1470> log likelihood: -118704
# INFO:lda:<1480> log likelihood: -118617
# INFO:lda:<1490> log likelihood: -118529
# INFO:lda:<1500> log likelihood: -118497
# INFO:lda:<1510> log likelihood: -118709
# INFO:lda:<1520> log likelihood: -118869
# INFO:lda:<1530> log likelihood: -118878
# INFO:lda:<1540> log likelihood: -118765
# INFO:lda:<1550> log likelihood: -118923
# INFO:lda:<1560> log likelihood: -118800
# INFO:lda:<1570> log likelihood: -118555
# INFO:lda:<1580> log likelihood: -118741
# INFO:lda:<1590> log likelihood: -118587
# INFO:lda:<1600> log likelihood: -118393
# INFO:lda:<1610> log likelihood: -118564
# INFO:lda:<1620> log likelihood: -118566
# INFO:lda:<1630> log likelihood: -118631
# INFO:lda:<1640> log likelihood: -118732
# INFO:lda:<1650> log likelihood: -118752
# INFO:lda:<1660> log likelihood: -118935
# INFO:lda:<1670> log likelihood: -118536
# INFO:lda:<1680> log likelihood: -118688
# INFO:lda:<1690> log likelihood: -118696
# INFO:lda:<1700> log likelihood: -118622
# INFO:lda:<1710> log likelihood: -118629
# INFO:lda:<1720> log likelihood: -118640
# INFO:lda:<1730> log likelihood: -118887
# INFO:lda:<1740> log likelihood: -118420
# INFO:lda:<1750> log likelihood: -118612
# INFO:lda:<1760> log likelihood: -118772
# INFO:lda:<1770> log likelihood: -118866
# INFO:lda:<1780> log likelihood: -118671
# INFO:lda:<1790> log likelihood: -118695
# INFO:lda:<1800> log likelihood: -118775
# INFO:lda:<1810> log likelihood: -118480
# INFO:lda:<1820> log likelihood: -118474
# INFO:lda:<1830> log likelihood: -118532
# INFO:lda:<1840> log likelihood: -118510
# INFO:lda:<1850> log likelihood: -118918
# INFO:lda:<1860> log likelihood: -118727
# INFO:lda:<1870> log likelihood: -118654
# INFO:lda:<1880> log likelihood: -118617
# INFO:lda:<1890> log likelihood: -118831
# INFO:lda:<1900> log likelihood: -118634
# INFO:lda:<1910> log likelihood: -118790
# INFO:lda:<1920> log likelihood: -118695
# INFO:lda:<1930> log likelihood: -118555
# INFO:lda:<1940> log likelihood: -118727
# INFO:lda:<1950> log likelihood: -118618
# INFO:lda:<1960> log likelihood: -118955
# INFO:lda:<1970> log likelihood: -118677
# INFO:lda:<1980> log likelihood: -118817
# INFO:lda:<1990> log likelihood: -118608
# INFO:lda:<2000> log likelihood: -118598
# INFO:lda:<2010> log likelihood: -118759
# INFO:lda:<2020> log likelihood: -118579
# INFO:lda:<2030> log likelihood: -118669
# INFO:lda:<2040> log likelihood: -118665
# INFO:lda:<2050> log likelihood: -118704
# INFO:lda:<2060> log likelihood: -118578
# INFO:lda:<2070> log likelihood: -118759
# INFO:lda:<2080> log likelihood: -118696
# INFO:lda:<2090> log likelihood: -118851
# INFO:lda:<2100> log likelihood: -118708
# INFO:lda:<2110> log likelihood: -118743
# INFO:lda:<2120> log likelihood: -118675
# INFO:lda:<2130> log likelihood: -118788
# INFO:lda:<2140> log likelihood: -118523
# INFO:lda:<2150> log likelihood: -118698
# INFO:lda:<2160> log likelihood: -118689
# INFO:lda:<2170> log likelihood: -118773
# INFO:lda:<2180> log likelihood: -118707
# INFO:lda:<2190> log likelihood: -118896
# INFO:lda:<2200> log likelihood: -118856
# INFO:lda:<2210> log likelihood: -118933
# INFO:lda:<2220> log likelihood: -118454
# INFO:lda:<2230> log likelihood: -118375
# INFO:lda:<2240> log likelihood: -118687
# INFO:lda:<2250> log likelihood: -118676
# INFO:lda:<2260> log likelihood: -118453
# INFO:lda:<2270> log likelihood: -118685
# INFO:lda:<2280> log likelihood: -118726
# INFO:lda:<2290> log likelihood: -118673
# INFO:lda:<2300> log likelihood: -118483
# INFO:lda:<2310> log likelihood: -118730
# INFO:lda:<2320> log likelihood: -118639
# INFO:lda:<2330> log likelihood: -118823
# INFO:lda:<2340> log likelihood: -118787
# INFO:lda:<2350> log likelihood: -118760
# INFO:lda:<2360> log likelihood: -118518
# INFO:lda:<2370> log likelihood: -118525
# INFO:lda:<2380> log likelihood: -118892
# INFO:lda:<2390> log likelihood: -118750
# INFO:lda:<2400> log likelihood: -118588
# INFO:lda:<2410> log likelihood: -118790
# INFO:lda:<2420> log likelihood: -118716
# INFO:lda:<2430> log likelihood: -118694
# INFO:lda:<2440> log likelihood: -118625
# INFO:lda:<2450> log likelihood: -118609
# INFO:lda:<2460> log likelihood: -118434
# INFO:lda:<2470> log likelihood: -118624
# INFO:lda:<2480> log likelihood: -118674
# INFO:lda:<2490> log likelihood: -118622
# INFO:lda:<2500> log likelihood: -118658
# INFO:lda:<2510> log likelihood: -118833
# INFO:lda:<2520> log likelihood: -118785
# INFO:lda:<2530> log likelihood: -118793
# INFO:lda:<2540> log likelihood: -118847
# INFO:lda:<2550> log likelihood: -118728
# INFO:lda:<2560> log likelihood: -118623
# INFO:lda:<2570> log likelihood: -118808
# INFO:lda:<2580> log likelihood: -118603
# INFO:lda:<2590> log likelihood: -118597
# INFO:lda:<2600> log likelihood: -118443
# INFO:lda:<2610> log likelihood: -118726
# INFO:lda:<2620> log likelihood: -118740
# INFO:lda:<2630> log likelihood: -118544
# INFO:lda:<2640> log likelihood: -118922
# INFO:lda:<2650> log likelihood: -118643
# INFO:lda:<2660> log likelihood: -118546
# INFO:lda:<2670> log likelihood: -118840
# INFO:lda:<2680> log likelihood: -118656
# INFO:lda:<2690> log likelihood: -118767
# INFO:lda:<2700> log likelihood: -118404
# INFO:lda:<2710> log likelihood: -118655
# INFO:lda:<2720> log likelihood: -118697
# INFO:lda:<2730> log likelihood: -118589
# INFO:lda:<2740> log likelihood: -118493
# INFO:lda:<2750> log likelihood: -118667
# INFO:lda:<2760> log likelihood: -118426
# INFO:lda:<2770> log likelihood: -118743
# INFO:lda:<2780> log likelihood: -118637
# INFO:lda:<2790> log likelihood: -118784
# INFO:lda:<2800> log likelihood: -118632
# INFO:lda:<2810> log likelihood: -118566
# INFO:lda:<2820> log likelihood: -118690
# INFO:lda:<2830> log likelihood: -118642
# INFO:lda:<2840> log likelihood: -118686
# INFO:lda:<2850> log likelihood: -118828
# INFO:lda:<2860> log likelihood: -118454
# INFO:lda:<2870> log likelihood: -118677
# INFO:lda:<2880> log likelihood: -118838
# INFO:lda:<2890> log likelihood: -118690
# INFO:lda:<2900> log likelihood: -118822
# INFO:lda:<2910> log likelihood: -118747
# INFO:lda:<2920> log likelihood: -118762
# INFO:lda:<2930> log likelihood: -118773
# INFO:lda:<2940> log likelihood: -118807
# INFO:lda:<2950> log likelihood: -118875
# INFO:lda:<2960> log likelihood: -118957
# INFO:lda:<2970> log likelihood: -118903
# INFO:lda:<2980> log likelihood: -118806
# INFO:lda:<2990> log likelihood: -118774
# INFO:lda:<3000> log likelihood: -118831
# INFO:lda:<3010> log likelihood: -118884
# INFO:lda:<3020> log likelihood: -118727
# INFO:lda:<3030> log likelihood: -118768
# INFO:lda:<3040> log likelihood: -118645
# INFO:lda:<3050> log likelihood: -118792
# INFO:lda:<3060> log likelihood: -118645
# INFO:lda:<3070> log likelihood: -118457
# INFO:lda:<3080> log likelihood: -118720
# INFO:lda:<3090> log likelihood: -118704
# INFO:lda:<3100> log likelihood: -118645
# INFO:lda:<3110> log likelihood: -118661
# INFO:lda:<3120> log likelihood: -118757
# INFO:lda:<3130> log likelihood: -118800
# INFO:lda:<3140> log likelihood: -118756
# INFO:lda:<3150> log likelihood: -118713
# INFO:lda:<3160> log likelihood: -118993
# INFO:lda:<3170> log likelihood: -118831
# INFO:lda:<3180> log likelihood: -118718
# INFO:lda:<3190> log likelihood: -118636
# INFO:lda:<3200> log likelihood: -118597
# INFO:lda:<3210> log likelihood: -118778
# INFO:lda:<3220> log likelihood: -118784
# INFO:lda:<3230> log likelihood: -118942
# INFO:lda:<3240> log likelihood: -118938
# INFO:lda:<3250> log likelihood: -118654
# INFO:lda:<3260> log likelihood: -118894
# INFO:lda:<3270> log likelihood: -118766
# INFO:lda:<3280> log likelihood: -118685
# INFO:lda:<3290> log likelihood: -118678
# INFO:lda:<3300> log likelihood: -118650
# INFO:lda:<3310> log likelihood: -118698
# INFO:lda:<3320> log likelihood: -118618
# INFO:lda:<3330> log likelihood: -118569
# INFO:lda:<3340> log likelihood: -118684
# INFO:lda:<3350> log likelihood: -118745
# INFO:lda:<3360> log likelihood: -118860
# INFO:lda:<3370> log likelihood: -118855
# INFO:lda:<3380> log likelihood: -118751
# INFO:lda:<3390> log likelihood: -118762
# INFO:lda:<3400> log likelihood: -118722
# INFO:lda:<3410> log likelihood: -118549
# INFO:lda:<3420> log likelihood: -118564
# INFO:lda:<3430> log likelihood: -118515
# INFO:lda:<3440> log likelihood: -118179
# INFO:lda:<3450> log likelihood: -118595
# INFO:lda:<3460> log likelihood: -118636
# INFO:lda:<3470> log likelihood: -118723
# INFO:lda:<3480> log likelihood: -118797
# INFO:lda:<3490> log likelihood: -118637
# INFO:lda:<3500> log likelihood: -118601
# INFO:lda:<3510> log likelihood: -118697
# INFO:lda:<3520> log likelihood: -118995
# INFO:lda:<3530> log likelihood: -118649
# INFO:lda:<3540> log likelihood: -118465
# INFO:lda:<3550> log likelihood: -118629
# INFO:lda:<3560> log likelihood: -118633
# INFO:lda:<3570> log likelihood: -118400
# INFO:lda:<3580> log likelihood: -118676
# INFO:lda:<3590> log likelihood: -118683
# INFO:lda:<3600> log likelihood: -118546
# INFO:lda:<3610> log likelihood: -118608
# INFO:lda:<3620> log likelihood: -118696
# INFO:lda:<3630> log likelihood: -118889
# INFO:lda:<3640> log likelihood: -118642
# INFO:lda:<3650> log likelihood: -118785
# INFO:lda:<3660> log likelihood: -118690
# INFO:lda:<3670> log likelihood: -118714
# INFO:lda:<3680> log likelihood: -118787
# INFO:lda:<3690> log likelihood: -118816
# INFO:lda:<3700> log likelihood: -118903
# INFO:lda:<3710> log likelihood: -118657
# INFO:lda:<3720> log likelihood: -118786
# INFO:lda:<3730> log likelihood: -118591
# INFO:lda:<3740> log likelihood: -118573
# INFO:lda:<3750> log likelihood: -118503
# INFO:lda:<3760> log likelihood: -118532
# INFO:lda:<3770> log likelihood: -118664
# INFO:lda:<3780> log likelihood: -118506
# INFO:lda:<3790> log likelihood: -118611
# INFO:lda:<3800> log likelihood: -118731
# INFO:lda:<3810> log likelihood: -118942
# INFO:lda:<3820> log likelihood: -118667
# INFO:lda:<3830> log likelihood: -118833
# INFO:lda:<3840> log likelihood: -118748
# INFO:lda:<3850> log likelihood: -118542
# INFO:lda:<3860> log likelihood: -118672
# INFO:lda:<3870> log likelihood: -118782
# INFO:lda:<3880> log likelihood: -118659
# INFO:lda:<3890> log likelihood: -118545
# INFO:lda:<3900> log likelihood: -118653
# INFO:lda:<3910> log likelihood: -118746
# INFO:lda:<3920> log likelihood: -118809
# INFO:lda:<3930> log likelihood: -118529
# INFO:lda:<3940> log likelihood: -118661
# INFO:lda:<3950> log likelihood: -118684
# INFO:lda:<3960> log likelihood: -118751
# INFO:lda:<3970> log likelihood: -118827
# INFO:lda:<3980> log likelihood: -118691
# INFO:lda:<3990> log likelihood: -118572
# INFO:lda:<4000> log likelihood: -118448
# INFO:lda:<4010> log likelihood: -119038
# INFO:lda:<4020> log likelihood: -118657
# INFO:lda:<4030> log likelihood: -118625
# INFO:lda:<4040> log likelihood: -118392
# INFO:lda:<4050> log likelihood: -118659
# INFO:lda:<4060> log likelihood: -118651
# INFO:lda:<4070> log likelihood: -118568
# INFO:lda:<4080> log likelihood: -118588
# INFO:lda:<4090> log likelihood: -118778
# INFO:lda:<4100> log likelihood: -119086
# INFO:lda:<4110> log likelihood: -118533
# INFO:lda:<4120> log likelihood: -118512
# INFO:lda:<4130> log likelihood: -118607
# INFO:lda:<4140> log likelihood: -118618
# INFO:lda:<4150> log likelihood: -118607
# INFO:lda:<4160> log likelihood: -118713
# INFO:lda:<4170> log likelihood: -118706
# INFO:lda:<4180> log likelihood: -118815
# INFO:lda:<4190> log likelihood: -119039
# INFO:lda:<4200> log likelihood: -118551
# INFO:lda:<4210> log likelihood: -118695
# INFO:lda:<4220> log likelihood: -118578
# INFO:lda:<4230> log likelihood: -118551
# INFO:lda:<4240> log likelihood: -118857
# INFO:lda:<4250> log likelihood: -118478
# INFO:lda:<4260> log likelihood: -118742
# INFO:lda:<4270> log likelihood: -118575
# INFO:lda:<4280> log likelihood: -118768
# INFO:lda:<4290> log likelihood: -118667
# INFO:lda:<4300> log likelihood: -118761
# INFO:lda:<4310> log likelihood: -118605
# INFO:lda:<4320> log likelihood: -118782
# INFO:lda:<4330> log likelihood: -118781
# INFO:lda:<4340> log likelihood: -118841
# INFO:lda:<4350> log likelihood: -118825
# INFO:lda:<4360> log likelihood: -118683
# INFO:lda:<4370> log likelihood: -118683
# INFO:lda:<4380> log likelihood: -118780
# INFO:lda:<4390> log likelihood: -118712
# INFO:lda:<4400> log likelihood: -118624
# INFO:lda:<4410> log likelihood: -118384
# INFO:lda:<4420> log likelihood: -118731
# INFO:lda:<4430> log likelihood: -118671
# INFO:lda:<4440> log likelihood: -118563
# INFO:lda:<4450> log likelihood: -118597
# INFO:lda:<4460> log likelihood: -118867
# INFO:lda:<4470> log likelihood: -118901
# INFO:lda:<4480> log likelihood: -118983
# INFO:lda:<4490> log likelihood: -118664
# INFO:lda:<4500> log likelihood: -118579
# INFO:lda:<4510> log likelihood: -118794
# INFO:lda:<4520> log likelihood: -118755
# INFO:lda:<4530> log likelihood: -118663
# INFO:lda:<4540> log likelihood: -118999
# INFO:lda:<4550> log likelihood: -119001
# INFO:lda:<4560> log likelihood: -118498
# INFO:lda:<4570> log likelihood: -118602
# INFO:lda:<4580> log likelihood: -118922
# INFO:lda:<4590> log likelihood: -118609
# INFO:lda:<4600> log likelihood: -118618
# INFO:lda:<4610> log likelihood: -118796
# INFO:lda:<4620> log likelihood: -118544
# INFO:lda:<4630> log likelihood: -118613
# INFO:lda:<4640> log likelihood: -118743
# INFO:lda:<4650> log likelihood: -118546
# INFO:lda:<4660> log likelihood: -118569
# INFO:lda:<4670> log likelihood: -118723
# INFO:lda:<4680> log likelihood: -118615
# INFO:lda:<4690> log likelihood: -118869
# INFO:lda:<4700> log likelihood: -118607
# INFO:lda:<4710> log likelihood: -118954
# INFO:lda:<4720> log likelihood: -118773
# INFO:lda:<4730> log likelihood: -118663
# INFO:lda:<4740> log likelihood: -118712
# INFO:lda:<4750> log likelihood: -118780
# INFO:lda:<4760> log likelihood: -118731
# INFO:lda:<4770> log likelihood: -118614
# INFO:lda:<4780> log likelihood: -118912
# INFO:lda:<4790> log likelihood: -118797
# INFO:lda:<4800> log likelihood: -118816
# INFO:lda:<4810> log likelihood: -118974
# INFO:lda:<4820> log likelihood: -118777
# INFO:lda:<4830> log likelihood: -118700
# INFO:lda:<4840> log likelihood: -118598
# INFO:lda:<4850> log likelihood: -118669
# INFO:lda:<4860> log likelihood: -118462
# INFO:lda:<4870> log likelihood: -118562
# INFO:lda:<4880> log likelihood: -118541
# INFO:lda:<4890> log likelihood: -118921
# INFO:lda:<4900> log likelihood: -118920
# INFO:lda:<4910> log likelihood: -118755
# INFO:lda:<4920> log likelihood: -118590
# INFO:lda:<4930> log likelihood: -118715
# INFO:lda:<4940> log likelihood: -118742
# INFO:lda:<4950> log likelihood: -118668
# INFO:lda:<4960> log likelihood: -118420
# INFO:lda:<4970> log likelihood: -118552
# INFO:lda:<4980> log likelihood: -118698
# INFO:lda:<4990> log likelihood: -118555
# INFO:lda:<4999> log likelihood: -118921
# Topic 0: gobernar    educación nacional reformar ley presidente sistema gratuidad social
# Topic 1: personar año país    pasar gente querer ir recibir encontrar
# Topic 2: jugar jugador copar chile club partir fútbol colo mil sentir
# Topic 3: millón pagar dólar club empresa $ operación región abogar año
# Topic 4:    político chile presidente procesar deber partir    señalar casar
# Topic 5: año       historia película julio the   estrenar canal

# %%
plt.plot(model.loglikelihoods_[5:])

# %%
#Generando algunos gráficos de los resultados
from matplotlib.pylab import hist, show

y=model.doc_topic_
#distribución de tópicos en todos los documentos
dist = sum(y)/len(noticias)
w=np.arange(0,true_k)
plt.bar(w,height=dist,alpha=0.5,tick_label=w)
show()

#distribución de tópicos en el documento 100
plt.bar(w,height=y[98],alpha=0.5,tick_label=w)
show()

#frecuencia de palabras por tópico
n_top_words=15
numo =np.arange(0,n_top_words)

for idx,topic in enumerate(model.topic_word_):
    d =[]
    s = []
    for i in topic.argsort()[:-n_top_words - 1:-1]:
          s.append(diccionario[i])
          d.append(topic[i])
    
    plt.barh(numo,width=d,alpha=0.5,tick_label=s)
    show()

# %%
#calculando cluster en base al tópico mas frecuente
z=[]
for i in range(len(noticias)):
    z.append(np.argmax(y[i]))
plt.scatter(range(99),z,c=z)
show()

#distribución de cluster de acuerdo a la definición anterior
hist(z,bins=np.arange(-0.5,5.6,1),alpha=0.5,rwidth=0.9,density=True)
show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº7: ¿Cómo se comparan estos resultados con los anteriores? ¿Qué puede decir de la convergencia de la estimación en este caso?
# </p></div>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #F8B4B4">
# <p>Considerando este ejemplo realice el análisis tópicos del set de datos de su elección disponible en <a href=  "https://drive.google.com/drive/folders/1rc_wTBvm2YLMPO4GK3mM2vjuEXlPN1JN?usp=sharing"> Carpeta en drive </a>
# Comente sus hallazgos </p> </div>
